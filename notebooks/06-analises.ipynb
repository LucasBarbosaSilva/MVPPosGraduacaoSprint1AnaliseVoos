# %%
# %sql
USE CATALOG mvp;
USE SCHEMA gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Quantidade de voos realizado por empresa aérea, por rota e variando por mês, semestre e ano:

# %%
# %sql
select id_empresa, nm_empresa from dim_empresa;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_empresa</th><th>nm_empresa</th></tr></thead><tbody><tr><td>1000220</td><td>ITAPEMIRIM TRANSPORTES AEREOS LTDA</td></tr><tr><td>1000584</td><td>ATA - AEROTÁXI ABAETÉ LTDA.</td></tr><tr><td>1000625</td><td>APUÍ TÁXI AÉREO S/A</td></tr><tr><td>1000687</td><td>AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)</td></tr><tr><td>1000711</td><td>OMNI TÁXI AÉREO S.A.</td></tr><tr><td>1000780</td><td>TOTAL LINHAS AÉREAS S.A.</td></tr><tr><td>1000831</td><td>SIDERAL LINHAS AÉREAS LTDA.</td></tr><tr><td>1000854</td><td>GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S.A.)</td></tr><tr><td>1000892</td><td>ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL LINHAS AÉREAS LTDA.)</td></tr><tr><td>1000909</td><td>AZUL LINHAS AÉREAS BRASILEIRAS S/A</td></tr><tr><td>1000927</td><td>MAP TRANSPORTES AÉREOS LTDA.</td></tr><tr><td>1001093</td><td>TAM LINHAS AÉREAS S.A.</td></tr><tr><td>1001101</td><td>PASSAREDO TRANSPORTES AÉREOS S.A.</td></tr><tr><td>1007104</td><td>AEROSUL LINHAS AÉREAS LTDA. (EX AEROSUL TÁXI AÉREO E AUSTEN)</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql import functions as F

id_empresa = input("Digite o id da empresa ('' para todos):")
sg_aeroporto_origem = input("Digite a sigla do aeroporto de origem ('' para todos):")
sg_aeroporto_destino = input("Digite a sigla do aeroporto de destino ('' para todos):")
ano = input("Digite o ano (2020-2024) ('' para todos):")
semestre = input("Digite o semestre (1-2) ('' para todos):")
mes = input("Digite o mês (1-12) ('' para todos):")

df = spark.sql(f"""
                select 
                    ap.sg_iata AS origem, 
                    ac.sg_iata as destino, 
                    d.nr_ano as ano, 
                    d.nr_semestre as semestre, 
                    d.nr_mes as mes, 
                    count(*) as qtde_voos
                from fact_voo v 
                inner join dim_aeroporto ap on v.pk_id_aerodromo_partida = ap.id_aerodromo
                inner join dim_aeroporto ac on v.pk_id_aerodromo_chegada = ac.id_aerodromo
                inner join dim_data d on v.pk_id_dt_partida = d.dt_voo 
                where v.pk_id_empresa LIKE '%{id_empresa}%' 
                AND ap.sg_iata LIKE '%{sg_aeroporto_origem}%'
                AND ac.sg_iata LIKE '%{sg_aeroporto_destino}%'
                AND d.nr_mes LIKE '%{mes}%'
                AND d.nr_semestre LIKE '%{semestre}%'
                AND d.nr_ano LIKE '%{ano}%'
                group by origem, destino, mes, ano, semestre
                order by ano, semestre, ano, semestre, mes
            """)
A</td><td>MCZ</td><td>2024</td><td>1</td><td>4</td><td>26</td></tr><tr><td>EZE</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>4</td></tr><tr><td>BSB</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>31</td></tr><tr><td>CNF</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>21</td></tr><tr><td>GIG</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>52</td></tr><tr><td>VCP</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>1</td></tr><tr><td>GRU</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>73</td></tr><tr><td>SSA</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>29</td></tr><tr><td>BSB</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>30</td></tr><tr><td>CNF</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>23</td></tr><tr><td>FOR</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>1</td></tr><tr><td>GRU</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>73</td></tr><tr><td>EZE</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>5</td></tr><tr><td>SSA</td><td>MCZ</td><td>2024</td><td>1</td><td>6</td><td>32</td></tr><tr><td>GIG</td><td ...

# %% [markdown]
# ## Total de passageiros transportados por empresa aérea, por rota e variando por mês, semestre e ano;

# %%
from pyspark.sql.window import Window
from pyspark.sql import functions as F

id_empresa = input("Digite o id da empresa ('' para todos):")
sg_aeroporto_origem = input("Digite a sigla do aeroporto de origem ('' para todos):")
sg_aeroporto_destino = input("Digite a sigla do aeroporto de destino ('' para todos):")
ano = input("Digite o ano (2020-2024) ('' para todos):")
semestre = input("Digite o semestre (1-2) ('' para todos):")
mes = input("Digite o mês (1-12) ('' para todos):")

nm_empresa = spark.sql(f"""
                select 
                    nm_empresa
                from dim_empresa
                where id_empresa LIKE '%{id_empresa}%'
            """).collect()[0].nm_empresa
print("Buscando resultados para a empresa:", nm_empresa)

df = spark.sql(f"""
                select 
                    ap.sg_iata AS origem, 
                    ac.sg_iata as destino, 
                    d.nr_ano as ano, 
                    d.nr_semestre as semestre, 
                    d.nr_mes as mes, 
                    sum(v.nr_passag_pagos) + sum(v.nr_passag_gratis) as tt_passageiros
                from fact_voo v 
                inner join dim_aeroporto ap on v.pk_id_aerodromo_partida = ap.id_aerodromo
                inner join dim_aeroporto ac on v.pk_id_aerodromo_chegada = ac.id_aerodromo
                inner join dim_data d on v.pk_id_dt_partida = d.dt_voo 
                where v.pk_id_empresa LIKE '%{id_empresa}%' 
                AND ap.sg_iata LIKE '%{sg_aeroporto_origem}%'
                AND ac.sg_iata LIKE '%{sg_aeroporto_destino}%'
                AND d.nr_mes LIKE '%{mes}%'
                AND d.nr_semestre LIKE '%{semestre}%'
                AND d.nr_ano LIKE '%{ano}%'
                group by origem, destino, mes, ano, semestre
                order by ano, semestre, ano, semestre, mes
            """)
print("Total de passageiros:", df.select(F.sum("tt_passageiros").alias("total")).collect()[0].total)
df.display()
# Out:
# Digite o id da empresa ('' para todos): 1001093
# Digite a sigla do aeroporto de origem ('' para todos): REC
# Digite a sigla do aeroporto de destino ('' para todos): MCZ
# Digite o ano (2020-2024) ('' para todos):
# Digite o semestre (1-2) ('' para todos):
# Digite o mês (1-12) ('' para todos):
# Buscando resultados para a empresa: TAM LINHAS AÉREAS S.A.
# Total de passageiros: 683
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>origem</th><th>destino</th><th>ano</th><th>semestre</th><th>mes</th><th>tt_passageiros</th></tr></thead><tbody><tr><td>REC</td><td>MCZ</td><td>2021</td><td>2</td><td>7</td><td>197</td></tr><tr><td>REC</td><td>MCZ</td><td>2022</td><td>1</td><td>3</td><td>170</td></tr><tr><td>REC</td><td>MCZ</td><td>2022</td><td>1</td><td>5</td><td>129</td></tr><tr><td>REC</td><td>MCZ</td><td>2022</td><td>2</td><td>7</td><td>59</td></tr><tr><td>REC</td><td>MCZ</td><td>2024</td><td>1</td><td>5</td><td>128</td></tr></tbody></table></div>

# %% [markdown]
# ## Quais as rotas com maior custo benefício baseado na relação entre passageiros pagantes e consumo de combustível, variando por mês, semestre e ano;

# %%
ano = input("Digite o ano (2020-2024) ('' para todos):")
semestre = input("Digite o semestre (1-2) ('' para todos):")
mes = input("Digite o mês (1-12) ('' para todos):")

df = spark.sql(f"""
        select 
            ap.sg_iata AS origem,
            ap.nm_aerodromo as aeroporto_origem,
            ap.sg_uf as uf_origem,
            ac.sg_iata as destino, 
            ac.nm_aerodromo as aeroporto_destino,
            ac.sg_uf as uf_destino,
            d.nr_ano as ano, 
            d.nr_semestre as semestre,
            d.nr_mes as mes,
            sum(v.lt_combustivel) litros_combustivel, 
            sum(v.nr_passag_pagos) passageiros_pagos, 
            (sum(v.lt_combustivel)/sum(v.nr_passag_pagos)) as custo_beneficio
        from fact_voo v
        inner join dim_aeroporto ap on v.pk_id_aerodromo_partida = ap.id_aerodromo
        inner join dim_aeroporto ac on v.pk_id_aerodromo_chegada = ac.id_aerodromo
        inner join dim_data d on v.pk_id_dt_partida = d.dt_voo
        WHERE d.nr_mes LIKE '%{mes}%'
        AND d.nr_semestre LIKE '%{semestre}%'
        AND d.nr_ano LIKE '%{ano}%'
        group by origem, aeroporto_origem, uf_origem, destino, aeroporto_destino, uf_destino, ano, semestre, mes
        order by custo_beneficio
        limit 10;
    """)

df.display()
# Out:
# Digite o ano (2020-2024) ('' para todos): 2024
# Digite o semestre (1-2) ('' para todos):
# Digite o mês (1-12) ('' para todos):
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>