# %%
# %sql
USE CATALOG mvp;
USE SCHEMA bronze;

# %% [markdown]
# Exemplos de valores para cada coluna:

# %%
tabela = "voos"
spark.sql(f"SELECT sg_empresa_iata FROM {tabela} where len(sg_empresa_iata) = (select max(len(sg_empresa_iata)) from {tabela})").show()
# Out:
# +---------------+
# |sg_empresa_iata|
# +---------------+
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            TS+|
# |            VV+|
# |            VV+|
# |            VV+|
# |            VV+|
# +---------------+

# %%
tabela = "voos"
colunas = [
  "id_basica",
  "id_empresa",
  "sg_empresa_icao",
  "sg_empresa_iata",
  "nm_empresa",
  "nm_pais",
  "ds_tipo_empresa",
  "nr_voo",
  "nr_singular",
  "id_tipo_linha",
  "cd_tipo_linha",
  "ds_tipo_linha",
  "ds_natureza_tipo_linha",
  "ds_servico_tipo_linha",
  "ds_natureza_etapa",
  "hr_partida_real",
  "dt_partida_real",
  "id_aerodromo_origem",
  "sg_icao_origem",
  "sg_iata_origem",
  "nm_aerodromo_origem",
  "nm_municipio_origem",
  "sg_uf_origem",
  "nm_regiao_origem",
  "nm_pais_origem",
  "nm_continente_origem",
  "hr_chegada_real",
  "dt_chegada_real",
  "id_equipamento",
  "sg_equipamento_icao",
  "ds_modelo",
  "ds_matricula",
  "id_aerodromo_destino",
  "sg_icao_destino",
  "sg_iata_destino",
  "nm_aerodromo_destino",
  "nm_municipio_destino",
  "sg_uf_destino",
  "nm_regiao_destino",
  "nm_pais_destino",
  "nm_continente_destino",
  "lt_combustivel",
  "nr_assentos_ofertados",
  "kg_payload",
  "km_distancia",
  "nr_passag_pagos",
  "nr_passag_gratis",
  "kg_bagagem_livre",
  "kg_bagagem_excesso",
  "kg_carga_paga",
  "kg_carga_gratis",
  "kg_correio",
  "nr_horas_voadas",
  "kg_peso",
  "nr_velocidade_media",
  "nr_pax_gratis_km",
  "nr_carga_paga_km",
  "nr_carga_gratis_km",
  "nr_correio_km",
  "nr_bagagem_paga_km",
  "nr_bagagem_gratis_km",
  "nr_ask",
  "nr_rpk",
  "nr_atk"
]
for coluna in colunas:
  print(f"Coluna: {coluna}")
  print("Exemplo de valores:")
  display(spark.sql(f"SELECT DISTINCT {coluna} FROM {tabela} LIMIT 5"))
  print("Min:")
  display(spark.sql(f"SELECT MIN({coluna}) FROM {tabela}"))
  print("Max:")
  display(spark.sql(f"SELECT MAX({coluna}) FROM {tabela}"))
  print("Min (Length):")
  display(spark.sql(f"SELECT MIN(LEN({coluna})) FROM {tabela}"))
  print("Max (Length):")
  display(spark.sql(f"SELECT MAX(LEN({coluna})) FROM {tabela}"))
  print("-"*20)
# Out:
# Coluna: id_basica
# Exemplo de valores:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_basica</th></tr></thead><tbody><tr><td>34051980</td></tr><tr><td>34067644</td></tr><tr><td>34040594</td></tr><tr><td>34113121</td></tr><tr><td>34056623</td></tr></tbody></table></div>
# Min:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
